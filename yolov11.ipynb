# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 418.0/476.0 GB disk)

# %%
from ultralytics import YOLO
from PIL import Image, ImageFilter
import os
import requests
import matplotlib
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
model = YOLO('yolo11m.pt')

# Train the model
model.train(
    data='cityscapes_yolov11.yaml',  # Path to dataset YAML file
    epochs=120,                  # Number of epochsa
    batch=4,                   # Batch size
    imgsz=1024                   # Image size
)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
model = YOLO('./runs/detect/2_train_foggy/weights/best.pt')
metrics = model.val(
    data='cityscapes_yolov11.yaml',  # Path to dataset YAML file
    imgsz=1024,            # Image size for validation
    batch=4,             # Batch size for validation
)
print(metrics)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11m summary (fused): 303 layers, 20,036,200 parameters, 0 gradients, 67.7 GFLOPs
# val: Scanning C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_Dataset\yolo_format\labels\val.cache... 492 images, 8 backgrounds, 0 corrupt: 100%|██████████| 500/500 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 125/125 [00:12<00:00, 10.03it/s]
#                    all        500       9792      0.687      0.579      0.625      0.427
#                 person        401       3278      0.722      0.619      0.675      0.426
#                    car        475       4524      0.831      0.749      0.811      0.623
#                  train         21         22        0.6      0.545      0.576      0.377
#                  rider        250        521      0.718      0.645      0.665      0.436
# ...

# %%
# Let's make inference on a sample model
# %matplotlib inline
sample_image_path = './aachen_000002_000019.png'
image = Image.open(sample_image_path)
results = model(sample_image_path)
annotated_image = results[0].plot()
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
# Out:
# image 1/1 c:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_YOLO\aachen_000002_000019.png: 512x1024 2 persons, 5 cars, 193.7ms
# Speed: 6.1ms preprocess, 193.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 1024)

# %%
# %matplotlib inline

import os
import random
import matplotlib.pyplot as plt
from PIL import Image

# Function to select and plot random images
def select_and_plot_random_images(source_dir, num_samples, grid_size=(3, 3), figsize=(12,10)):
    """
    Select a given number of random images from subdirectories of the source directory
    and plot them in a grid using matplotlib.

    Parameters:
        source_dir (str): Path to the source directory containing subdirectories of images.
        num_samples (int): Number of random samples to select.
        grid_size (tuple): Grid size for plotting (rows, columns).
    """
    all_images = []

    # Collect all image file paths
    for root, _, files in os.walk(source_dir):
        for file in files:
            if file.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".gif")):
                all_images.append(os.path.join(root, file))

    if num_samples > len(all_images):
        raise ValueError("Number of samples exceeds the total number of images available.")

    # Randomly select images
    selected_images = random.sample(all_images, num_samples)

    # Plot the images in a grid
    fig, axes = plt.subplots(grid_size[0], grid_size[1], figsize=figsize)
    axes = axes.flatten()

    for ax, img_path in zip(axes, selected_images):
        img = Image.open(img_path)
        ax.imshow(img)
        ax.axis('off')

    # Hide any extra axes
    for ax in axes[len(selected_images):]:
        ax.axis('off')

    plt.tight_layout()
    plt.show()

source_directory = r"C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_Dataset\data"
number_of_samples = 9 
grid_dimensions = (3, 3)

select_and_plot_random_images(source_directory, number_of_samples, grid_dimensions, figsize=(15,8))

# %%
import cv2
import numpy as np

def dark_channel_prior(image, window_size=15):
    # Minimum across color channels
    min_channel = np.min(image, axis=2)
    # Apply erosion to get the dark channel
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (window_size, window_size))
    dark_channel = cv2.erode(min_channel, kernel)
    return dark_channel

def estimate_atmospheric_light(image, dark_channel, top_percent=0.001):
    # Flatten the dark channel
    h, w = dark_channel.shape
    num_pixels = h * w
    num_brightest = int(max(num_pixels * top_percent, 1))
    
    # Get indices of top dark_channel values
    dark_vec = dark_channel.ravel()
    image_vec = image.reshape(num_pixels, 3)
    indices = np.argsort(dark_vec)[-num_brightest:]
    
    # Atmos. light is mean of these brightest pixels in original image
    atmo_light = np.mean(image_vec[indices], axis=0)
    return atmo_light

def estimate_transmission(image, atmospheric_light, omega=0.95, window_size=15):
    # Normalize by atmospheric light
    norm_image = image / atmospheric_light
    # Compute dark channel of normalized image
    dark_channel_norm = dark_channel_prior(norm_image, window_size)
    # Estimate transmission
    transmission = 1 - omega * dark_channel_norm
    return transmission

def guided_filter(I, p, radius, eps):
    # Guided filter to refine the transmission map
    mean_I = cv2.boxFilter(I, cv2.CV_64F, (radius, radius))
    mean_p = cv2.boxFilter(p, cv2.CV_64F, (radius, radius))
    mean_Ip = cv2.boxFilter(I * p, cv2.CV_64F, (radius, radius))
    cov_Ip = mean_Ip - mean_I * mean_p

    mean_II = cv2.boxFilter(I * I, cv2.CV_64F, (radius, radius))
    var_I = mean_II - mean_I * mean_I

    a = cov_Ip / (var_I + eps)
    b = mean_p - a * mean_I

    mean_a = cv2.boxFilter(a, cv2.CV_64F, (radius, radius))
    mean_b = cv2.boxFilter(b, cv2.CV_64F, (radius, radius))

    q = mean_a * I + mean_b
    return q

def recover_image(image, transmission, atmospheric_light, t_min=0.1):
    # Ensure transmission isn’t too low
    transmission = np.maximum(transmission, t_min)
    # Expand dims for broadcasting
    transmission_3d = np.expand_dims(transmission, axis=2)
    J = (image - atmospheric_light) / transmission_3d + atmospheric_light
    return np.clip(J, 0, 1)

def dehaze(image_path):
    # Read image
    image = cv2.imread(image_path)
    # Convert BGR to RGB and normalize
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) / 255.0

    # Steps:
    dark = dark_channel_prior(image)
    A = estimate_atmospheric_light(image, dark)
    raw_t = estimate_transmission(image, A)

    # Refine transmission using guided filter
    gray = cv2.cvtColor((image * 255).astype(np.uint8), cv2.COLOR_RGB2GRAY) / 255.0
    refined_t = guided_filter(gray, raw_t, radius=60, eps=1e-3)

    # Recover haze-free image
    dehazed = recover_image(image, refined_t, A)
    dehazed_bgr = cv2.cvtColor((dehazed * 255).astype(np.uint8), cv2.COLOR_RGB2BGR)
    return dehazed_bgr

def gamma_correction(image, gamma):
    # Avoid division by zero and ensure gamma is positive
    gamma = max(gamma, 1e-8)
    
    # Compute the inverse gamma value
    inv_gamma = 1.0 / gamma

    # Build a lookup table to speed up the pixel value transformation
    # The table maps each input pixel value [0..255] to its gamma-corrected output
    table = np.array([(i / 255.0) ** inv_gamma * 255 for i in range(256)]).astype("uint8")

    # Apply the lookup table to the input image
    corrected = cv2.LUT(image, table)
    return corrected

def apply_clahe(img, clipLimit=2.0, tileGridSize=(8,8)):
    # Convert from BGR to Lab color space
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    
    # Split into L, a, b channels
    l, a, b = cv2.split(lab)
    
    # Create CLAHE object
    clahe = cv2.createCLAHE(clipLimit=clipLimit, tileGridSize=tileGridSize)
    
    # Apply CLAHE on the L channel
    l_clahe = clahe.apply(l)
    
    # Merge the channels back
    lab_clahe = cv2.merge((l_clahe, a, b))
    
    # Convert back to BGR color space
    img_clahe = cv2.cvtColor(lab_clahe, cv2.COLOR_LAB2BGR)
    return img_clahe

# %%
# %matplotlib inline
output_image = "dehazed_image.png"

sample_image_path = './aachen_000002_000019.png'
sample_no_fog_image_path = './aachen_000002_000019_original.png'

original_image = cv2.imread(sample_image_path)
original_no_fog_image = cv2.imread(sample_no_fog_image_path)

dehazed_image = dehaze(sample_image_path)
gamma=2.2
gamma_corrected = gamma_correction(dehazed_image, gamma=gamma)

clahe_image = apply_clahe(gamma_corrected)

plt.figure(figsize=(12, 10))

plt.subplot(3, 2, 1)
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Foggy Image")
plt.axis('off')

plt.subplot(3, 2, 2)
plt.imshow(cv2.cvtColor(dehazed_image, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Dehaze")
plt.axis('off')

plt.subplot(3, 2, 3)
plt.imshow(cv2.cvtColor(gamma_corrected, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title(f"Gamma Correction (Gamma={gamma})")
plt.axis('off')

plt.subplot(3, 2, 4)
plt.imshow(cv2.cvtColor(clahe_image, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Contrast Limited Adaptive Histogram Equalization")
plt.axis('off')

pil_img = Image.fromarray(clahe_image)
enhanced_image = np.array(pil_img.filter(ImageFilter.EDGE_ENHANCE_MORE))
plt.subplot(3, 2, 5)
plt.imshow(cv2.cvtColor(enhanced_image, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Edge Enhancement")
plt.axis('off')

plt.subplot(3, 2, 6)
plt.imshow(cv2.cvtColor(original_no_fog_image, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Original Image (No Synthetic Fog)")
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
def preprocess_images(target_dir, output_dir, apply_dehaze=True, gcorr=True, clahe=True, edenh=True, gamma=2.2):
    """
    Applies gamma correction to all .png images in target_dir and saves them to output_dir,
    preserving the directory structure.
    """
    for root, dirs, files in os.walk(target_dir):
        # Construct relative path from target directory to current directory
        rel_path = os.path.relpath(root, target_dir)
        # Create corresponding directory in output directory
        output_sub_dir = os.path.join(output_dir, rel_path)
        if not os.path.exists(output_sub_dir):
            os.makedirs(output_sub_dir, exist_ok=True)

        for file_name in files:
            if file_name.lower().endswith('.png'):
                target_file_path = os.path.join(root, file_name)
                output_file_path = os.path.join(output_sub_dir, file_name)

                # Open the image
                with Image.open(target_file_path) as img:
                    # Convert image to RGB if not already
                    img = img.convert('RGB')
                    # Apply gamma correction
                    if (True == apply_dehaze):
                        img = dehaze(target_file_path)

                    if (True == gcorr):
                        img = gamma_correction(img, gamma)

                    if (True == clahe):
                        img = apply_clahe(img)

                    if (True == edenh):
                        pil_img = Image.fromarray(img)
                        img = np.array(pil_img.filter(ImageFilter.EDGE_ENHANCE_MORE))

                    # Save the corrected image
                    cv2.imwrite(output_file_path, img)

original_dataset_path = "C:/Users/101081/Desktop/Advc.Topics/Project/Foggy_CityScapes_Dataset/yolo_format"
processed_dataset_path = "C:/Users/101081/Desktop/Advc.Topics/Project/Foggy_CityScapes_Dataset/dehaze_gc_2_8"

preprocess_images(original_dataset_path, processed_dataset_path, apply_dehaze=True, gcorr=True, clahe=False, edenh=False, gamma=2.8)

# %%
model = YOLO('yolo11m.pt')

# Train the model
model.train(
    data='cityscapes_dehazed_yolov11.yaml',  # Path to dataset YAML file
    epochs=120,                  # Number of epochsa
    batch=4,                   # Batch size
    imgsz=1024                   # Image size
)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
model = YOLO('./runs/detect/8_train_dehaze_gc_2_2/weights/best.pt')
metrics = model.val(
    data='cityscapes_dehazed_yolov11.yaml',  # Path to dataset YAML file
    imgsz=1024,            # Image size for validation
    batch=4,             # Batch size for validation
)
print(metrics)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11m summary (fused): 303 layers, 20,036,200 parameters, 0 gradients, 67.7 GFLOPs
# val: Scanning C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_Dataset\dehazed\labels\val.cache... 492 images, 8 backgrounds, 0 corrupt: 100%|██████████| 500/500 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 125/125 [00:13<00:00,  9.44it/s]
#                    all        500       9792       0.77      0.573      0.651      0.441
#                 person        401       3278      0.793      0.586      0.678      0.435
#                    car        475       4524      0.877      0.716      0.812      0.623
#                  train         21         22      0.697      0.636      0.661      0.438
#                  rider        250        521      0.787      0.612      0.678      0.443
# ...

# %%
model = YOLO('yolo11m.pt')

# Train the model
model.train(
    data='cityscapes_clahe_yolov11.yaml',  # Path to dataset YAML file
    epochs=120,                  # Number of epochsa
    batch=4,                   # Batch size
    imgsz=1024                   # Image size
)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
model = YOLO('yolo11m.pt')

# Train the model
model.train(
    data='cityscapes_no_gcorr_yolov11.yaml',  # Path to dataset YAML file
    epochs=120,                  # Number of epochsa
    batch=4,                   # Batch size
    imgsz=1024                   # Image size
)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
model = YOLO('yolo11m.pt')

# Train the model
model.train(
    data='cityscapes_no_clahe_yolov11.yaml',  # Path to dataset YAML file
    epochs=120,                  # Number of epochsa
    batch=4,                   # Batch size
    imgsz=1024                   # Image size
)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
model = YOLO('yolo11m.pt')

# Train the model
model.train(
    data='cityscapes_no_edenh_yolov11.yaml',  # Path to dataset YAML file
    epochs=120,                  # Number of epochsa
    batch=4,                   # Batch size
    imgsz=1024                   # Image size
)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
model = YOLO('yolo11m.pt')

# Train the model
model.train(
    data='cityscapes_dehazed_clahe_nogc_yolov11.yaml',  # Path to dataset YAML file
    epochs=120,                  # Number of epochs
    batch=4,                   # Batch size
    imgsz=1024                   # Image size
)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
model = YOLO('yolo11m.pt')

# Train the model
model.train(
    data='cityscapes_no_fog_yolov11.yaml',  # Path to dataset YAML file
    epochs=120,                  # Number of epochsa
    batch=4,                   # Batch size
    imgsz=1024                   # Image size
)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
model = YOLO('yolo11m.pt')

# Train the model
model.train(
    data='cityscapes_dehaze_gc16.yaml',  # Path to dataset YAML file
    epochs=120,                  # Number of epochsa
    batch=4,                   # Batch size
    imgsz=1024                   # Image size
)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
model = YOLO('yolo11m.pt')

# Train the model
model.train(
    data='cityscapes_dehaze_gc28.yaml',  # Path to dataset YAML file
    epochs=120,                  # Number of epochsa
    batch=4,                   # Batch size
    imgsz=1024                   # Image size
)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
# GC dataset model results on original dataset

model = YOLO('./runs/detect/8_train_dehaze_gc_2_2/weights/best.pt')

metrics = model.val(
    data='cityscapes_no_fog_yolov11.yaml',  # Path to dataset YAML file
    imgsz=1024,            # Image size for validation
    batch=4,             # Batch size for validation
)

print(metrics)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11m summary (fused): 303 layers, 20,036,200 parameters, 0 gradients, 67.7 GFLOPs
# val: Scanning C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_Dataset\no_fog\labels\val.cache... 492 images, 8 backgrounds, 0 corrupt: 100%|██████████| 500/500 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 125/125 [00:13<00:00,  9.24it/s]
#                    all        500       9792      0.754      0.518      0.598      0.399
#                 person        401       3278      0.814      0.543      0.663      0.425
#                    car        475       4524      0.901      0.684        0.8      0.616
#                  train         21         22      0.474      0.545      0.532      0.335
#                  rider        250        521       0.83      0.534       0.65       0.42
# ...

# %%
# GC dataset model results on foggy dataset

model = YOLO('./runs/detect/8_train_dehaze_gc_2_2/weights/best.pt')

metrics = model.val(
    data='cityscapes_yolov11.yaml',  # Path to dataset YAML file
    imgsz=1024,            # Image size for validation
    batch=4,             # Batch size for validation
)

print(metrics)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11m summary (fused): 303 layers, 20,036,200 parameters, 0 gradients, 67.7 GFLOPs
# val: Scanning C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_Dataset\yolo_format\labels\val.cache... 492 images, 8 backgrounds, 0 corrupt: 100%|██████████| 500/500 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 125/125 [00:13<00:00,  9.45it/s]
#                    all        500       9792       0.75      0.489      0.578      0.394
#                 person        401       3278      0.845      0.503       0.64      0.408
#                    car        475       4524        0.9      0.667      0.793      0.602
#                  train         21         22      0.567      0.409      0.421      0.286
#                  rider        250        521      0.786      0.579      0.644      0.423
# ...

# %%
# Original dataset model results on foggy dataset

model = YOLO('./runs/detect/1_train_original/weights/best.pt')

metrics = model.val(
    data='cityscapes_yolov11.yaml',  # Path to dataset YAML file
    imgsz=1024,            # Image size for validation
    batch=4,             # Batch size for validation
)

print(metrics)
# Out:
# Ultralytics 8.3.40  Python-3.12.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11m summary (fused): 303 layers, 20,036,200 parameters, 0 gradients, 67.7 GFLOPs
# val: Scanning C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_Dataset\yolo_format\labels\val.cache... 492 images, 8 backgrounds, 0 corrupt: 100%|██████████| 500/500 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 125/125 [00:13<00:00,  9.33it/s]
#                    all        500       9792      0.688      0.483      0.526       0.35
#                 person        401       3278      0.683      0.572      0.612      0.395
#                    car        475       4524      0.814      0.663      0.732      0.564
#                  train         21         22      0.655      0.345      0.373      0.151
#                  rider        250        521      0.691      0.593      0.626      0.417
# ...

# %%
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 26})
results_1 = cv2.imread(r"C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_YOLO\runs\detect\1_train_original\PR_curve.png")
results_2 = cv2.imread(r"C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_YOLO\runs\detect\2_train_foggy\PR_curve.png")
results_3 = cv2.imread(r"C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_YOLO\runs\detect\3_train_dehaze_gc_clahe_edenh\PR_curve.png")
results_4 = cv2.imread(r"C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_YOLO\runs\detect\4_train_dehaze_clahe_edenh\PR_curve.png")
results_5 = cv2.imread(r"C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_YOLO\runs\detect\5_train_dehaze_gc_edenh\PR_curve.png")
results_6 = cv2.imread(r"C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_YOLO\runs\detect\6_train_dehaze_gc_clahe\PR_curve.png")
results_7 = cv2.imread(r"C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_YOLO\runs\detect\7_train_dehaze_clahe\PR_curve.png")
results_8 = cv2.imread(r"C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_YOLO\runs\detect\8_train_dehaze_gc_2_2\PR_curve.png")
results_9 = cv2.imread(r"C:\Users\101081\Desktop\Advc.Topics\Project\Foggy_CityScapes_YOLO\runs\detect\9_train_dehaze_gc_1_6\PR_curve.png")

plt.figure(figsize=(60, 40))

plt.subplot(3, 3, 1)
plt.imshow(cv2.cvtColor(results_2, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Foggy Dataset")
plt.axis('off')

plt.subplot(3, 3, 2)
plt.imshow(cv2.cvtColor(results_3, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title(f"Dehaze + GC + HE + EE")
plt.axis('off')

plt.subplot(3, 3, 3)
plt.imshow(cv2.cvtColor(results_4, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Dehaze + HE + EE")
plt.axis('off')

plt.subplot(3, 3, 4)
plt.imshow(cv2.cvtColor(results_5, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Dehaze + GC + EE")
plt.axis('off')

plt.subplot(3, 3, 5)
plt.imshow(cv2.cvtColor(results_6, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Dehaze + GC + HE")
plt.axis('off')

plt.subplot(3, 3, 6)
plt.imshow(cv2.cvtColor(results_7, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Dehaze + HE")
plt.axis('off')

plt.subplot(3, 3, 7)
plt.imshow(cv2.cvtColor(results_9, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Dehaze + GC (Gamma=1.6)")
plt.axis('off')

plt.subplot(3, 3, 8)
plt.imshow(cv2.cvtColor(results_8, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Dehaze + GC (Gamma=2.2)")
plt.axis('off')

plt.subplot(3, 3, 9)
plt.imshow(cv2.cvtColor(results_1, cv2.COLOR_BGR2RGB), cmap='gray')
plt.title("Original Dataset (No Fog)")
plt.axis('off')

plt.tight_layout()
plt.show()
